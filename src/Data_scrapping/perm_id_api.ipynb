# %%
# !pip install OpenPermID

# %%
from OpenPermID import OpenPermID
import pandas as pd
import time
from random import randint
from time import sleep

# %% [markdown]
# ### Pass in the API keys from other notebook

# %%
# pass in key
# %run ./perm_id_key.ipynb

# %%
# initiate OpenPermID
opid = OpenPermID()
opid.set_access_token(access_token)

# %% [markdown]
# ### Importing the names that we gathered using the boerse-frankfurt website

# %%
# import boerse list
boerse_path = r'/Users/gabbyvinco/Desktop/boerse_list.csv'
boerse = pd.read_csv(boerse_path, index_col=None, header=0)

# %%
boerse = boerse["0"].tolist()

# %%
# boerse

# %% [markdown]
# ### Importing the names that we gathered using Google search

# %%
# import google list
goog_path = r'/Users/gabbyvinco/Desktop/google_list.csv'
google = pd.read_csv(goog_path, index_col=None, header=0)

# %%
# google

# %%
google = google["0"].tolist()

# %%
# google

# %% [markdown]
# ### Importing the names that we gathered using the cbonds website

# %%
# import cbonds list
cbonds_path = r'/Users/gabbyvinco/Desktop/cbonds_list.csv'
cbonds = pd.read_csv(cbonds_path, index_col=None, header=0)

# %%
cbonds = cbonds["0"].tolist()

# %%
# cbonds

# %% [markdown]
# ### Using the names from the excel data that we got from the links on project instructions

# %%
# import the contents of CSPP_PEPP_corporate_bond_holdings_20210430 into a dataframe
# corporate_bond_holdings_df = pd.read_excel (r'/Users/gabbyvinco/Desktop/CSPP_PEPP_corporate_bond_holdings_20210430.xlsx')

# %%
# remove accents from companies in ISSUER column
# corporate_bond_holdings_df['ISSUER'] = corporate_bond_holdings_df['ISSUER'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# %%
# create a list of unique ISSUERS to run through the API
# unique_issuers = corporate_bond_holdings_df["ISSUER"].unique()
# unique_issuers

# %%
# len(unique_issuers)

# %%
# create a test run to make sure the function is working properly
# test_run = unique_issuers[:4]
# test_run

# %% [markdown]
# ### First Function: Searching the API by company names
#
# #### Here the issue is that when you perform a search, it returns up to 5 results per search. Unless the name is specifically what is listed in the API it will provide you with multiple results, and the first result is not always the one that we want. Although for the sake of this section in the project we are trying to find the industry/sector of the company and if we provide an accurate enough search name the results will vary very slightly and all still belong to the same mother company.
# #### (i.e SIX Financial Information Luxembourg SA and SIX Finance Luxembourg SA)

# %%
# create a list to add the data frames from the name search
companies_list = []

# %%
# function for using the unique_issuers to find an ID number by name search
def search_company_name(unique_companies):

    for company in unique_companies:
        # this is setup to retry if the search doesn't work on the first time
        # upon using the website I noticed that it took a few times upon manual entry
        # for the search results to appear
        for attempt in range(3):
            try:
                # first attempt
                output,err = opid.search(company)
                companies_list.append(output["organizations"])
                print("df added try 1")
            except:
                # next attempt
                print("extra break hold on a minute")
                # add an extra break
                time.sleep(10)
                output,err = opid.search(company)
                companies_list.append(output["organizations"])
                print("df added on try 2")
            else:
                break
        else:
            print(company)
            print("there were no entries for this company")
            pass
        time.sleep(10)
    print("done")

# %%
# run the search by name function
search_company_name(boerse)
# Out:
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# extra break hold on a minute
# df added on try 2
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# extra break hold on a minute
# df added on try 2
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# extra break hold on a minute
# df added on try 2
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# extra break hold on a minute
# df added on try 2
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# extra break hold on a minute
# df added on try 2
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# extra break hold on a minute
# df added on try 2
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# extra break hold on a minute
# df added on try 2
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# extra break hold on a minute
# df added on try 2
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# df added try 1
# done

# %%
# take the list of individual dataframes and concatenate them into one

# goog_companies_df = pd.concat(companies_list)
boerse_companies_df = pd.concat(companies_list)

# %%
# save the df to csv file
# boerse_companies_df.to_csv (r'/Users/gabbyvinco/Desktop/boerse_companies_df.csv', index = False, header=True)

# %%
# using names from google scraping
# goog_companies_df.head(50)

# using names from boerse scraping
boerse_companies_df.head(50)
# Out:
#                                @id  \
# 0  https://permid.org/1-5076357523
# 1  https://permid.org/1-5035086734
# 0  https://permid.org/1-4295858951
# 0  https://permid.org/1-5035081777
# 1  https://permid.org/1-5076374471
# 2  https://permid.org/1-4298274049
# 3  https://permid.org/1-5035086656
# 4  https://permid.org/1-5035081956
# 0  https://permid.org/1-5057739178
# 1  https://permid.org/1-5000919567
# 0  https://permid.org/1-5057817730
# 0  https://permid.org/1-4296432601
# 0  https://permid.org/1-5000002567
# 1  https://permid.org/1-5000038105
# 0  https://permid.org/1-5001439044
# 0  https://permid.org/1-5051785981
# 1  https://permid.org/1-5071074208
# 0  https://permid.org/1-4295908720
# 1  https://permid.org/1-5000446029
# 2  https://permid.org/1-4295905753
# 3  https://permid.org/1-4296446248
# 4  https://permid.org/1-5000722930
# 0  https://permid.org/1-4295889552
# 0  https://permid.org/1-4296672845
# 1  https://permid.org/1-4296612476
# 2  https://permid.org/1-4296108083
# 3  https://permid.org/1-4296953120
# 4  https://permid.org/1-4296868838
# 0  https://permid.org/1-5044014420
# 0  https://permid.org/1-4295868312
# 1  https://permid.org/1-5001147432
# 0  https://permid.org/1-5040945174
# 1  https://permid.org/1-5039933317
# 2  https://permid.org/1-5076163128
# 3  https://permid.org/1-5060050568
# 4  https://permid.org/1-5043439676
# 0  https://permid.org/1-4298205141
# 0  https://permid.org/1-4295866806
# 1  https://permid.org/1-4295859411
# 2  https://permid.org/1-4295860016
# 3  https://permid.org/1-4295863424
# 4  https://permid.org/1-5045849327
# 0  https://permid.org/1-5079903944
# 0  https://permid.org/1-4298050903
# 1  https://permid.org/1-5001094595
# 0  https://permid.org/1-4295866614
# 1  https://permid.org/1-5036769925
# 2  https://permid.org/1-4296721674
# 3  https://permid.org/1-5001387082
# 4  https://permid.org/1-5036761760
#
#                                     organizationName               orgSubtype  \
# 0                          SIX Finance Luxembourg SA                  Company
# 1            SIX Financial Information Luxembourg SA                  Company
# 0                           CA Immobilien Anlagen AG                     REIT
# 0                               Klepierre Athinon SA                  Company
# 1                      Klepierre Finance Belgique SA                  Unknown
# 2                             Klepierre Makedonia SA                  Company
# 3                   Klepierre Management Portugal SA                  Company
# 4                       Klepierre Peribola Patras SA                  Company
# 0  Societe des Autoroutes du Nord et de l'Est de ...                  Unknown
# 1  Societe Des Autoroutes Du Nord Et De Lest De La F                  Company
# 0                         Deutsche Bahn Finance GmbH  Special Purpose Vehicle
# 0                             Basf Finance Europe NV  Special Purpose Vehicle
# 0                            Michelin Luxembourg SCS                  Company
# 1                     Michelin Invest Luxembourg SCS                  Company
# 0                             Fresenius SE & Co KGaA                  Company
# 0                         Eaton Capital Unlimited Co                  Company
# 1         Eaton Capital Global Holdings Unlimited Co                  Unknown
# 0                           Agilent Technologies Inc                  Company
# 1                    Samuel A. Ramirez & Company Inc                  Company
# 2                                Books-A-Million Inc                  Company
# 3     A Menarini Industrie Farmaceutiche Riunite Srl                  Company
# 4                                Innisfree M & A Inc                  Company
# 0                  Prosegur Compania de Seguridad SA                  Company
# 0                                 FIST SPA(VALEO SA)                  Company
# 1                                   KLAXON(VALEO SA)                  Company
# 2                                   NEIMAN(VALEO SA)                  Company
# 3                          PAUL JOURNEE SA(VALEO SA)                  Company
# 4                         PLASTICOS UNIVEL(VALEO SA)                  Company
# 0                                   Indigo Group SAS                  Company
# 0                                          Wendel SE       Investment Company
# 1                           Wendel Participations SE                  Company
# 0                                        CEPD CTP BV                  Unknown
# 1                                     CTP Holding BV                  Company
# 2                                             CTP NV                  Company
# 3                                    CTP Pensioen BV                  Unknown
# 4                                    CTP Products BV                  Unknown
# 0                  Nortegas Energia Distribucion SAU                  Company
# 0                                           Engie SA                  Company
# 1                                      Electrabel SA                  Company
# 2                            Engie Brasil Energia SA                  Company
# 3                             ENGIE Energia Chile SA                  Company
# 4                                       Engie Eps SA                  Company
# 0                           DSV Panalpina Finance BV                  Company
# 0                                         STRABAG SE                  Company
# 1                              Bauholding StrabAG Se                  Company
# 0                                          Sodexo SA                  Company
# 1                                Sodexo Argentina Sa                  Unknown
# 2                                  Sodexo Belgium SA                  Company
# 3                                    Sodexo Chile SA                  Unknown
# 4                                 Sodexo Colombia Sa                  Unknown
#
#   primaryTicker hasHoldingClassification  \
# 0           NaN                      NaN
# 1           NaN                      NaN
# 0           CAI             publiclyHeld
# 0           NaN                      NaN
# 1           NaN                      NaN
# 2           NaN                      NaN
# 3           NaN                      NaN
# 4           NaN                      NaN
# 0           NaN                      NaN
# 1           NaN                      NaN
# 0           NaN                      NaN
# 0           NaN                      NaN
# 0           NaN                      NaN
# 1           NaN                      NaN
# 0           FRE             publiclyHeld
# 0           NaN                      NaN
# 1           NaN                      NaN
# 0             A             publiclyHeld
# 1           NaN                      NaN
# 2           NaN                      NaN
# 3           NaN                      NaN
# 4           NaN                      NaN
# 0           PSG             publiclyHeld
# 0           NaN                      NaN
# 1           NaN                      NaN
# 2           NaN                      NaN
# 3           NaN                      NaN
# 4           NaN                      NaN
# 0           NaN                      NaN
# 0            MF             publiclyHeld
# 1           NaN                      NaN
# 0           NaN                      NaN
# 1           NaN                      NaN
# 2         CTPNV             publiclyHeld
# 3           NaN                      NaN
# 4           NaN                      NaN
# 0           NaN                      NaN
# 0          ENGI             publiclyHeld
# 1          ELEB                      NaN
# 2         EGIE3             publiclyHeld
# 3           ECL             publiclyHeld
# 4           EPS             publiclyHeld
# 0           NaN                      NaN
# 0           STR             publiclyHeld
# 1           NaN                      NaN
# 0            SW             publiclyHeld
# 1           NaN                      NaN
# 2           NaN                      NaN
# 3           NaN                      NaN
# 4           NaN                      NaN
#
#                                               hasURL
# 0                                                NaN
# 1                                                NaN
# 0                            https://www.caimmo.com/
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  http://www.segece.pt/92-11088-Pagina-principal...
# 4                                                NaN
# 0                                                NaN
# 1                                                NaN
# 0  https://ir.deutschebahn.com/de/anleihen-rating...
# 0                                                NaN
# 0  https://www.michelin.com/eng/finance/regulated...
# 1                                                NaN
# 0                         https://www.fresenius.com/
# 0                                                NaN
# 1                                                NaN
# 0                           https://www.agilent.com/
# 1                          http://www.ramirezco.com/
# 2                      http://www.booksamillion.com/
# 3                            http://www.menarini.it/
# 4                        http://www.innisfreema.com/
# 0                           http://www.prosegur.com/
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 0                      https://www.group-indigo.com/
# 0                       https://www.wendelgroup.com/
# 1                                                NaN
# 0                                                NaN
# 1                                                NaN
# 2                                https://www.ctp.eu/
# 3                                                NaN
# 4                                                NaN
# 0                               https://nortegas.es/
# 0                             https://www.engie.com/
# 1                    https://www.engie-electrabel.be
# 2                 http://www.tractebelenergia.com.br
# 3                          https://engie-energia.cl/
# 4                             https://engie-eps.com/
# 0                                                NaN
# 0                            http://www.strabag.com/
# 1                                                NaN
# 0                            https://www.sodexo.com/
# 1                                                NaN
# 2             http://be.sodexo.com/befr/default.aspx
# 3                                                NaN
# 4                                                NaN

# %%
# sort by index because for each search term there were up to 5 responses. by sorting all of the first responses
# will have an index of 0. However there were only about 331 values with index of 0, so I decided it would be best
# to keep all the indexes up until 2 (the first 3 responses from the search term, which is up until the 615 row)
boerse_companies_df = boerse_companies_df.sort_index()

# %%
boerse_companies_df = boerse_companies_df.reset_index()
# companies_df

# %%
boerse_companies_df
# Out:
#      index                              @id  \
# 0        0  https://permid.org/1-5076357523
# 1        0  https://permid.org/1-5074787774
# 2        0  https://permid.org/1-4296784388
# 3        0  https://permid.org/1-4298015165
# 4        0  https://permid.org/1-4297959131
# ..     ...                              ...
# 681      4  https://permid.org/1-4298222835
# 682      4  https://permid.org/1-4297571030
# 683      4  https://permid.org/1-4296661285
# 684      4  https://permid.org/1-4297279373
# 685      4  https://permid.org/1-5000637697
#
#                            organizationName               orgSubtype  \
# 0                 SIX Finance Luxembourg SA                  Company
# 1                        Balder Finland Oyj                  Company
# 2      Siemens Financieringsmaatschappij NV  Special Purpose Vehicle
# 3                              NetSuite Inc                  Company
# 4            Wurth Finance International BV                  Company
# ..                                      ...                      ...
# 681                    Carrefour Romania SA                  Company
# 682             Safran Landing Systems SASU                  Company
# 683                      Groupe Liaisons SA                  Company
# 684          Assurances De La Poste Non Vie                  Company
# 685  Axa Real Estate Investment Managers SA                  Company
#
#     primaryTicker hasHoldingClassification  \
# 0             NaN                      NaN
# 1             NaN                      NaN
# 2             NaN                      NaN
# 3               N                      NaN
# 4             NaN                      NaN
# ..            ...                      ...
# 681           NaN                      NaN
# 682           NaN                      NaN
# 683           NaN                      NaN
# 684           NaN                      NaN
# 685           NaN                      NaN
#
#                                      hasURL
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                  http://www.netsuite.com/
# 4              http://www.wuerthfinance.net
# ..                                      ...
# 681                http://www.carrefour.ro/
# 682  http://www.safran-landing-systems.com/
# 683                      http://www.lamy.fr
# 684                                     NaN
# 685           https://realassets.axa-im.com
#
# [686 rows x 7 columns]

# %%
boerse_companies_first = boerse_companies_df.loc[boerse_companies_df['index'] == 0]
boerse_companies_first
# Out:
#      index                              @id  \
# 0        0  https://permid.org/1-5076357523
# 1        0  https://permid.org/1-5074787774
# 2        0  https://permid.org/1-4296784388
# 3        0  https://permid.org/1-4298015165
# 4        0  https://permid.org/1-4297959131
# ..     ...                              ...
# 323      0  https://permid.org/1-4296672845
# 324      0  https://permid.org/1-5001421091
# 325      0  https://permid.org/1-5037846601
# 326      0  https://permid.org/1-4295889552
# 327      0  https://permid.org/1-4298169984
#
#                          organizationName               orgSubtype  \
# 0               SIX Finance Luxembourg SA                  Company
# 1                      Balder Finland Oyj                  Company
# 2    Siemens Financieringsmaatschappij NV  Special Purpose Vehicle
# 3                            NetSuite Inc                  Company
# 4          Wurth Finance International BV                  Company
# ..                                    ...                      ...
# 323                    FIST SPA(VALEO SA)                  Company
# 324         Brisa Concessao Rodoviaria SA                  Company
# 325             Enagas Financiaciones SAU                  Company
# 326     Prosegur Compania de Seguridad SA                  Company
# 327                  HELLA GmbH & Co KGaA                  Company
#
#     primaryTicker hasHoldingClassification                         hasURL
# 0             NaN                      NaN                            NaN
# 1             NaN                      NaN                            NaN
# 2             NaN                      NaN                            NaN
# 3               N                      NaN       http://www.netsuite.com/
# 4             NaN                      NaN   http://www.wuerthfinance.net
# ..            ...                      ...                            ...
# 323           NaN                      NaN                            NaN
# 324           NaN                      NaN  http://www.brisaconcessao.pt/
# 325           NaN                      NaN                            NaN
# 326           PSG             publiclyHeld       http://www.prosegur.com/
# 327           HLE             publiclyHeld         https://www.hella.com/
#
# [328 rows x 7 columns]

# %%
# create a tester list for the extra company info function
# tester = companies_df.iloc[:4,:]

# %% [markdown]
# ### Second Function: using the PermID url ("@id" column) do a further lookup with the API

# %%
# create a new list to add the outputs fromt he extra company info function
companies_info = []

# %%
# function for using the companies_df to take the perm id number and get more info about the company
def grab_extra_company_info(df):
    for item in range(len(df)):
        for attempt in range(3):
            # another multiple attempts feature included in this lookup
            try:
                # first attempt
                perm_id = companies_df['@id'].iloc[item][-12:]
                output,err = opid.lookup(perm_id, format="dataframe")
                companies_info.append(output)
                print("extra info added try 1")
            except:
                # second attempt
                print("extra break hold on a minute")
                time.sleep(10)
                perm_id = companies_df['@id'].iloc[item][-12:]
                output,err = opid.lookup(perm_id, format="dataframe")
                companies_info.append(output)
                print("extra info added on try 2")
            else:
                break
        else:
            print(company)
            print("there was no extra info for this company")
            pass
        time.sleep(10)
    print("done")

# %%
# run the extra info function 
grab_extra_company_info(companies_df)
# Out:
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra break hold on a minute
# extra info added on try 2
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra break hold on a minute
# extra info added on try 2
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra break hold on a minute
# extra info added on try 2
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra break hold on a minute
# extra info added on try 2
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# extra info added try 1
# done

# %%
# concatenate all of the dataframes from companies_info list into one dataframe
companies_info_df = pd.concat(companies_info)

# %%
# companies_info_df

# %%
companies_info_df = companies_info_df.reset_index(drop=True)
companies_info_df
# Out:
#                                  @id                @type tr-common:hasPermId  \
# 0    https://permid.org/1-5071549731  tr-org:Organization          5071549731
# 1    https://permid.org/1-5057817730  tr-org:Organization          5057817730
# 2    https://permid.org/1-4296543170  tr-org:Organization          4296543170
# 3    https://permid.org/1-4296653814  tr-org:Organization          4296653814
# 4    https://permid.org/1-4296930961  tr-org:Organization          4296930961
# ..                               ...                  ...                 ...
# 448  https://permid.org/1-4296680912  tr-org:Organization          4296680912
# 449  https://permid.org/1-4296858525  tr-org:Organization          4296858525
# 450  https://permid.org/1-5067178704  tr-org:Organization          5067178704
# 451  https://permid.org/1-4296730050  tr-org:Organization          4296730050
# 452  https://permid.org/1-4296152148  tr-org:Organization          4296152148
#
#                              mdaas:HeadquartersAddress  \
# 0    Boulevard De L'empereur 20\nBRUXELLES\nBRUXELL...
# 1    c/o Deutsche Bahn Aktiengesellschaft\nEuropapl...
# 2    Stationsplein 8 K\nMAASTRICHT\nLIMBURG\n6221BT...
# 3    Willemsplein 4\nS-HERTOGENBOSCH\nNOORD-BRABANT...
# 4    Herikerbergweg 122\nAMSTERDAM\nNOORD-HOLLAND\n...
# ..                                                 ...
# 448  Rua Lauro Mullerm, 116 Sala 3902 e 3903\nRio D...
# 449  Challenger\n1, avenue Eugene Freyssinet\nSAINT...
# 450                                          Hungary\n
# 451  25 Rue De Clichy\nPARIS\nILE-DE-FRANCE\n75009\...
# 452                                      Ff\nGermany\n
#
#                                mdaas:RegisteredAddress    hasActivityStatus  \
# 0    Boulevard De L'empereur 20\nBRUXELLES\nBRUXELL...  tr-org:statusActive
# 1    c/o Deutsche Bahn Aktiengesellschaft\nEuropapl...  tr-org:statusActive
# 2    Stationsplein 8 K\nMAASTRICHT\nLIMBURG\n6221BT...  tr-org:statusActive
# 3    Willemsplein 4\nS-HERTOGENBOSCH\nNOORD-BRABANT...  tr-org:statusActive
# 4    Herikerbergweg 122\nAMSTERDAM\nNOORD-HOLLAND\n...  tr-org:statusActive
# ..                                                 ...                  ...
# 448                                                NaN  tr-org:statusActive
# 449  Challenger\n1 Av Eugene Freyssinet\nGUYANCOURT...  tr-org:statusActive
# 450                                                NaN  tr-org:statusActive
# 451  25 Rue De Clichy\nParis 9\nPARIS\nILE-DE-FRANC...  tr-org:statusActive
# 452                                                NaN  tr-org:statusActive
#
#             tr-org:hasLEI hasLatestOrganizationFoundedDate  \
# 0    549300A3EZXECDLW2V25             2019-07-31T00:00:00Z
# 1    52990002BAIDUAIIYU29             2017-09-01T00:00:00Z
# 2    529900ERDFHS6C1M4U58                              NaN
# 3    5299005PIU82TA2PW123             2001-02-14T00:00:00Z
# 4    724500CNCIO1ZTJ0X675             2001-04-03T00:00:00Z
# ..                    ...                              ...
# 448                   NaN             1995-01-01T00:00:00Z
# 449  969500IL7U7UEI5ZYJ34             1982-07-01T00:00:00Z
# 450                   NaN                              NaN
# 451  549300850GMPCX5CK282             2006-02-28T00:00:00Z
# 452                   NaN                              NaN
#
#             hasPrimaryBusinessSector         hasPrimaryEconomicSector  ...  \
# 0    https://permid.org/1-4294952820  https://permid.org/1-4294952821  ...
# 1    https://permid.org/1-4294952739  https://permid.org/1-4294952740  ...
# 2    https://permid.org/1-4294952825  https://permid.org/1-4294952723  ...
# 3    https://permid.org/1-4294952820  https://permid.org/1-4294952821  ...
# 4    https://permid.org/1-4294952820  https://permid.org/1-4294952821  ...
# ..                               ...                              ...  ...
# 448  https://permid.org/1-4294952773  https://permid.org/1-4294952774  ...
# 449  https://permid.org/1-4294952762  https://permid.org/1-4294952767  ...
# 450  https://permid.org/1-4294952860  https://permid.org/1-1004365438  ...
# 451  https://permid.org/1-4294952739  https://permid.org/1-4294952740  ...
# 452  https://permid.org/1-4294952745  https://permid.org/1-4294952746  ...
#
#     tr-org:hasHeadquartersPhoneNumber tr-org:hasRegisteredPhoneNumber  \
# 0                                 NaN                             NaN
# 1                        493029764006                    493029764006
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ..                                ...                             ...
# 448                      552125080505                             NaN
# 449                       33130603300                     33130603300
# 450                               NaN                             NaN
# 451                       33140758000                             NaN
# 452                               NaN                             NaN
#
#                                                 hasURL  \
# 0                                                  NaN
# 1    https://ir.deutschebahn.com/de/anleihen-rating...
# 2                             https://www.telekom.com/
# 3                                                  NaN
# 4    https://www.enbw.com/company/investors/bonds/e...
# ..                                                 ...
# 448                        http://www.lorentzen.com.br
# 449               http://www.bouygues-construction.com
# 450                                                NaN
# 451                                                NaN
# 452                                                NaN
#
#     hasOrganizationPrimaryQuote hasPrimaryInstrument  \
# 0                           NaN                  NaN
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
# ..                          ...                  ...
# 448                         NaN                  NaN
# 449                         NaN                  NaN
# 450                         NaN                  NaN
# 451                         NaN                  NaN
# 452                         NaN                  NaN
#
#     tr-org:hasHeadquartersFaxNumber hasHoldingClassification hasIPODate  \
# 0                               NaN                      NaN        NaN
# 1                               NaN                      NaN        NaN
# 2                               NaN                      NaN        NaN
# 3                               NaN                      NaN        NaN
# 4                               NaN                      NaN        NaN
# ..                              ...                      ...        ...
# 448                             NaN                      NaN        NaN
# 449                     33130604861                      NaN        NaN
# 450                             NaN                      NaN        NaN
# 451                     33145635728                      NaN        NaN
# 452                             NaN                      NaN        NaN
#
#     tr-org:hasRegisteredFaxNumber hasInactiveDate
# 0                             NaN             NaN
# 1                             NaN             NaN
# 2                             NaN             NaN
# 3                             NaN             NaN
# 4                             NaN             NaN
# ..                            ...             ...
# 448                           NaN             NaN
# 449                   33130604861             NaN
# 450                           NaN             NaN
# 451                           NaN             NaN
# 452                           NaN             NaN
#
# [453 rows x 24 columns]

# %%
# save the df to csv file
# companies_info_df.to_csv (r'/Users/gabbyvinco/Desktop/companies_info.csv', index = False, header=True)

# %%
# only keep companies whose buisness sector row is not NaN
companies_info_df = companies_info_df[companies_info_df['hasPrimaryBusinessSector'].notna()]

# %%
# create a test_list for the buisness sector function
test_list = companies_info_df.iloc[:4,:]
# test_list

# %% [markdown]
# ### Third Function: using the business sector id ("hasPrimaryBusinessSector") to perform another lookup

# %%
# create a new list to hold the information about what buiness sector the companies are in
industry_info = []

# %%
# function to find out industry info
def grab_sector_info(df):
    for item in range(len(df)):
        for attempt in range(3):
            # another multiple attempts feature included in this lookup
            try:
                # first attempt
                business_sector_id = companies_info_df['hasPrimaryBusinessSector'].iloc[item][-12:]
                output,err = opid.lookup(business_sector_id, format="dataframe")
                industry_info.append(output)
                print("sector info added try 1")
            except:
                # second attempt
                print("extra break hold on a minute")
                time.sleep(10)
                business_sector_id = companies_info_df['hasPrimaryBusinessSector'].iloc[item][-12:]
                output,err = opid.lookup(business_sector_id, format="dataframe")
                industry_info.append(output)
                print("sector info added on try 2")
            else:
                break
        else:
            print(company)
            print("there was no sector info for this company")
            pass
        time.sleep(10)
    print("done")

# %%
# run the function to get the industry info
grab_sector_info(companies_info_df)
# Out:
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# sector info added try 1
# done

# %%
# concatenate the industry info dataframes into one
company_sectors_df = pd.concat(industry_info)
# company_sectors_df

# %%
company_sectors_df = company_sectors_df.reset_index(drop=True)
# company_sectors_df

# %%
# save the df to csv file
# company_sectors_df.to_csv (r'/Users/gabbyvinco/Desktop/company_sectors.csv', index = False, header=True)

# %%
# rename the @id column in company_sectors_df to match the column name in companies_info_df ('hasPrimaryBusinessSector')
company_sectors_df = company_sectors_df.rename(columns={'@id': 'hasPrimaryBusinessSector'})
# company_sectors_df

# %%
# merge company_sectors_df into companies_info_df
full_company_info_df = pd.concat([company_sectors_df, companies_info_df.reindex(companies_info_df.index)], axis=1)
# full_company_info_df.head()

# %%
complete_companies_df = full_company_info_df[['@id','@type','tr-common:hasPermId','trbc:BusinessClassificationCode','rdfs:label','prefLabel','rdfs:comment','hasPrimaryBusinessSector','hasPrimaryEconomicSector','tr-org:hasLEI','mdaas:HeadquartersAddress','tr-org:hasHeadquartersPhoneNumber','hasURL']].copy()
# complete_companies_df.head()

# %%
complete_companies_df['type_keep'] = complete_companies_df.iloc[:,2]
complete_companies_df['org_perm_id'] = complete_companies_df.iloc[:,4]
complete_companies_df['sector_perm_id'] = complete_companies_df.iloc[:,3]

# %%
complete_companies_df = complete_companies_df.drop(['@type', 'tr-common:hasPermId','hasPrimaryBusinessSector'], axis=1)

# %%
complete_companies_df.head()
# Out:
#                                @id trbc:BusinessClassificationCode  \
# 0  https://permid.org/1-5071549731                            5910
# 2  https://permid.org/1-4296543170                            5740
# 3  https://permid.org/1-4296653814                            5910
# 4  https://permid.org/1-4296930961                            5910
# 5  https://permid.org/1-4296072717                            5510
#
#                       rdfs:label                      prefLabel  \
# 0                      Utilities                      Utilities
# 2    Telecommunications Services    Telecommunications Services
# 3                      Utilities                      Utilities
# 4                      Utilities                      Utilities
# 5  Banking & Investment Services  Banking & Investment Services
#
#                                         rdfs:comment  \
# 0  Producers and distributors of electricity, nat...
# 2  Owners and operators of fixed line and wireles...
# 3  Producers and distributors of electricity, nat...
# 4  Producers and distributors of electricity, nat...
# 5  Providers of retail, commercial and investment...
#
#           hasPrimaryEconomicSector         tr-org:hasLEI  \
# 0  https://permid.org/1-4294952821  549300A3EZXECDLW2V25
# 2  https://permid.org/1-4294952723  529900ERDFHS6C1M4U58
# 3  https://permid.org/1-4294952821  5299005PIU82TA2PW123
# 4  https://permid.org/1-4294952821  724500CNCIO1ZTJ0X675
# 5  https://permid.org/1-4294952740  549300TG53AWJ719M814
#
#                            mdaas:HeadquartersAddress  \
# 0  Boulevard De L'empereur 20\nBRUXELLES\nBRUXELL...
# 2  Stationsplein 8 K\nMAASTRICHT\nLIMBURG\n6221BT...
# 3  Willemsplein 4\nS-HERTOGENBOSCH\nNOORD-BRABANT...
# 4  Herikerbergweg 122\nAMSTERDAM\nNOORD-HOLLAND\n...
# 5  Kabelweg 37\nAMSTERDAM\nNOORD-HOLLAND\n1014 BA...
#
#   tr-org:hasHeadquartersPhoneNumber  \
# 0                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
#
#                                               hasURL            type_keep  \
# 0                                                NaN  tr-org:Organization
# 2                           https://www.telekom.com/  tr-org:Organization
# 3                                                NaN  tr-org:Organization
# 4  https://www.enbw.com/company/investors/bonds/e...  tr-org:Organization
# 5  https://www.eon.com/de/investoren/anleihen/e-d...  tr-org:Organization
#
#   org_perm_id sector_perm_id
# 0  5071549731     4294952820
# 2  4296543170     4294952825
# 3  4296653814     4294952820
# 4  4296930961     4294952820
# 5  4296072717     4294952739

# %%
companies_firstresult_df = companies_df[companies_df['index'] == 0]

# %%
companies_firstresult_df = companies_firstresult_df.drop(['index'], axis=1)
companies_firstresult_df
# Out:
#                                  @id  \
# 0    https://permid.org/1-5071549731
# 1    https://permid.org/1-5057817730
# 2    https://permid.org/1-4296543170
# 3    https://permid.org/1-4296653814
# 4    https://permid.org/1-4296930961
# ..                               ...
# 327  https://permid.org/1-5042958012
# 328  https://permid.org/1-4295867357
# 329  https://permid.org/1-4298361219
# 330  https://permid.org/1-4295867538
# 331  https://permid.org/1-4295867411
#
#                                       organizationName  \
# 0                         Elia Transmission Belgium NV
# 1                           Deutsche Bahn Finance GmbH
# 2            Deutsche Telekom International Finance BV
# 3                                    innogy Finance BV
# 4                        EnBW International Finance BV
# ..                                                 ...
# 327                                        Euronext NV
# 328                               Dassault Systemes SE
# 329                                            DNA Oyj
# 330                                           Vinci SA
# 331  Compagnie Generale des Etablissements Michelin...
#
#                   orgSubtype  \
# 0                    Company
# 1    Special Purpose Vehicle
# 2    Special Purpose Vehicle
# 3    Special Purpose Vehicle
# 4    Special Purpose Vehicle
# ..                       ...
# 327                  Company
# 328                  Company
# 329                  Company
# 330                  Company
# 331                  Company
#
#                                                 hasURL primaryTicker  \
# 0                                                  NaN           NaN
# 1    https://ir.deutschebahn.com/de/anleihen-rating...           NaN
# 2                             https://www.telekom.com/           NaN
# 3                                                  NaN           NaN
# 4    https://www.enbw.com/company/investors/bonds/e...           NaN
# ..                                                 ...           ...
# 327                          https://www.euronext.com/           ENX
# 328                                https://www.3ds.com           DSY
# 329                                https://www.dna.fi/           DNA
# 330                             https://www.vinci.com/            DG
# 331                           https://www.michelin.fr/            ML
#
#     hasHoldingClassification
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 327             publiclyHeld
# 328             publiclyHeld
# 329                      NaN
# 330             publiclyHeld
# 331             publiclyHeld
#
# [332 rows x 6 columns]

# %% [markdown]
# ### Combine all of the dataframes together and clean

# %%
# join complete_companies_df and companies_firstresult_df
# final_df = pd.concat([complete_companies_df, companies_firstresult_df], axis=1, join="inner")

# or use companies_df instead of companies_firstresult_df
final_df = pd.concat([complete_companies_df, companies_df], axis=1, join="inner")

# %%
final_df
# Out:
#                                  @id trbc:BusinessClassificationCode  \
# 0    https://permid.org/1-5071549731                            5910
# 2    https://permid.org/1-4296543170                            5740
# 3    https://permid.org/1-4296653814                            5910
# 4    https://permid.org/1-4296930961                            5910
# 5    https://permid.org/1-4296072717                            5510
# ..                               ...                             ...
# 448  https://permid.org/1-4296680912                            5120
# 449  https://permid.org/1-4296858525                            5220
# 450  https://permid.org/1-5067178704                            6010
# 451  https://permid.org/1-4296730050                            5510
# 452  https://permid.org/1-4296152148                            5320
#
#                            rdfs:label                         prefLabel  \
# 0                           Utilities                         Utilities
# 2         Telecommunications Services       Telecommunications Services
# 3                           Utilities                         Utilities
# 4                           Utilities                         Utilities
# 5       Banking & Investment Services     Banking & Investment Services
# ..                                ...                               ...
# 448                 Mineral Resources                 Mineral Resources
# 449  Industrial & Commercial Services  Industrial & Commercial Services
# 450                       Real Estate                       Real Estate
# 451     Banking & Investment Services     Banking & Investment Services
# 452        Cyclical Consumer Products        Cyclical Consumer Products
#
#                                           rdfs:comment  \
# 0    Producers and distributors of electricity, nat...
# 2    Owners and operators of fixed line and wireles...
# 3    Producers and distributors of electricity, nat...
# 4    Producers and distributors of electricity, nat...
# 5    Providers of retail, commercial and investment...
# ..                                                 ...
# 448  Miners and processors of steel, aluminum, prec...
# 449  Providers of construction, engineering, commer...
# 450  Developers and managers of real estate operati...
# 451  Providers of retail, commercial and investment...
# 452  Manufacturers and producers of durable goods s...
#
#             hasPrimaryEconomicSector         tr-org:hasLEI  \
# 0    https://permid.org/1-4294952821  549300A3EZXECDLW2V25
# 2    https://permid.org/1-4294952723  529900ERDFHS6C1M4U58
# 3    https://permid.org/1-4294952821  5299005PIU82TA2PW123
# 4    https://permid.org/1-4294952821  724500CNCIO1ZTJ0X675
# 5    https://permid.org/1-4294952740  549300TG53AWJ719M814
# ..                               ...                   ...
# 448  https://permid.org/1-4294952774                   NaN
# 449  https://permid.org/1-4294952767  969500IL7U7UEI5ZYJ34
# 450  https://permid.org/1-1004365438                   NaN
# 451  https://permid.org/1-4294952740  549300850GMPCX5CK282
# 452  https://permid.org/1-4294952746                   NaN
#
#                              mdaas:HeadquartersAddress  \
# 0    Boulevard De L'empereur 20\nBRUXELLES\nBRUXELL...
# 2    Stationsplein 8 K\nMAASTRICHT\nLIMBURG\n6221BT...
# 3    Willemsplein 4\nS-HERTOGENBOSCH\nNOORD-BRABANT...
# 4    Herikerbergweg 122\nAMSTERDAM\nNOORD-HOLLAND\n...
# 5    Kabelweg 37\nAMSTERDAM\nNOORD-HOLLAND\n1014 BA...
# ..                                                 ...
# 448  Rua Lauro Mullerm, 116 Sala 3902 e 3903\nRio D...
# 449  Challenger\n1, avenue Eugene Freyssinet\nSAINT...
# 450                                          Hungary\n
# 451  25 Rue De Clichy\nPARIS\nILE-DE-FRANCE\n75009\...
# 452                                      Ff\nGermany\n
#
#     tr-org:hasHeadquartersPhoneNumber  \
# 0                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# ..                                ...
# 448                      552125080505
# 449                       33130603300
# 450                               NaN
# 451                       33140758000
# 452                               NaN
#
#                                                 hasURL  ... org_perm_id  \
# 0                                                  NaN  ...  5071549731
# 2                             https://www.telekom.com/  ...  4296543170
# 3                                                  NaN  ...  4296653814
# 4    https://www.enbw.com/company/investors/bonds/e...  ...  4296930961
# 5    https://www.eon.com/de/investoren/anleihen/e-d...  ...  4296072717
# ..                                                 ...  ...         ...
# 448                        http://www.lorentzen.com.br  ...  4296680912
# 449               http://www.bouygues-construction.com  ...  4296858525
# 450                                                NaN  ...  5067178704
# 451                                                NaN  ...  4296730050
# 452                                                NaN  ...  4296152148
#
#     sector_perm_id level_0  index                              @id  \
# 0       4294952820       0      0  https://permid.org/1-5071549731
# 2       4294952825       2      0  https://permid.org/1-4296543170
# 3       4294952820       3      0  https://permid.org/1-4296653814
# 4       4294952820       4      0  https://permid.org/1-4296930961
# 5       4294952739       5      0  https://permid.org/1-4296072717
# ..             ...     ...    ...                              ...
# 448     4294952773     448      1  https://permid.org/1-4296716646
# 449     4294952762     449      1  https://permid.org/1-4296716646
# 450     4294952860     450      1  https://permid.org/1-4297270573
# 451     4294952739     451      1  https://permid.org/1-5074666524
# 452     4294952745     452      1  https://permid.org/1-4295867730
#
#                               organizationName               orgSubtype  \
# 0                 Elia Transmission Belgium NV                  Company
# 2    Deutsche Telekom International Finance BV  Special Purpose Vehicle
# 3                            innogy Finance BV  Special Purpose Vehicle
# 4                EnBW International Finance BV  Special Purpose Vehicle
# 5                E On International Finance BV  Special Purpose Vehicle
# ..                                         ...                      ...
# 448                   Reseaux Cables De France                  Company
# 449                   Reseaux Cables De France                  Company
# 450               Befimmo Property Services SA                  Company
# 451         Brussels Airport Terminal Co SA NV                  Unknown
# 452                           Solvay France SA                  Company
#
#                                                 hasURL primaryTicker  \
# 0                                                  NaN           NaN
# 2                             https://www.telekom.com/           NaN
# 3                                                  NaN           NaN
# 4    https://www.enbw.com/company/investors/bonds/e...           NaN
# 5    https://www.eon.com/de/investoren/anleihen/e-d...           NaN
# ..                                                 ...           ...
# 448                                                NaN           NaN
# 449                                                NaN           NaN
# 450                                                NaN           NaN
# 451                                                NaN           NaN
# 452                                                NaN           RHA
#
#     hasHoldingClassification
# 0                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# ..                       ...
# 448                      NaN
# 449                      NaN
# 450                      NaN
# 451                      NaN
# 452                      NaN
#
# [451 rows x 21 columns]

# %%
final_df['org_url'] = final_df.iloc[:,9]
final_df['id'] = final_df.iloc[:,0]

# %%
final_df = final_df.drop(['@id', 'rdfs:label','hasURL','type_keep'], axis=1)

# %%
final_df.head()
# Out:
#   trbc:BusinessClassificationCode                      prefLabel  \
# 0                            5910                      Utilities
# 2                            5740    Telecommunications Services
# 3                            5910                      Utilities
# 4                            5910                      Utilities
# 5                            5510  Banking & Investment Services
#
#                                         rdfs:comment  \
# 0  Producers and distributors of electricity, nat...
# 2  Owners and operators of fixed line and wireles...
# 3  Producers and distributors of electricity, nat...
# 4  Producers and distributors of electricity, nat...
# 5  Providers of retail, commercial and investment...
#
#           hasPrimaryEconomicSector         tr-org:hasLEI  \
# 0  https://permid.org/1-4294952821  549300A3EZXECDLW2V25
# 2  https://permid.org/1-4294952723  529900ERDFHS6C1M4U58
# 3  https://permid.org/1-4294952821  5299005PIU82TA2PW123
# 4  https://permid.org/1-4294952821  724500CNCIO1ZTJ0X675
# 5  https://permid.org/1-4294952740  549300TG53AWJ719M814
#
#                            mdaas:HeadquartersAddress  \
# 0  Boulevard De L'empereur 20\nBRUXELLES\nBRUXELL...
# 2  Stationsplein 8 K\nMAASTRICHT\nLIMBURG\n6221BT...
# 3  Willemsplein 4\nS-HERTOGENBOSCH\nNOORD-BRABANT...
# 4  Herikerbergweg 122\nAMSTERDAM\nNOORD-HOLLAND\n...
# 5  Kabelweg 37\nAMSTERDAM\nNOORD-HOLLAND\n1014 BA...
#
#   tr-org:hasHeadquartersPhoneNumber org_perm_id sector_perm_id  level_0  \
# 0                               NaN  5071549731     4294952820        0
# 2                               NaN  4296543170     4294952825        2
# 3                               NaN  4296653814     4294952820        3
# 4                               NaN  4296930961     4294952820        4
# 5                               NaN  4296072717     4294952739        5
#
#    index                           organizationName               orgSubtype  \
# 0      0               Elia Transmission Belgium NV                  Company
# 2      0  Deutsche Telekom International Finance BV  Special Purpose Vehicle
# 3      0                          innogy Finance BV  Special Purpose Vehicle
# 4      0              EnBW International Finance BV  Special Purpose Vehicle
# 5      0              E On International Finance BV  Special Purpose Vehicle
#
#   primaryTicker hasHoldingClassification  \
# 0           NaN                      NaN
# 2           NaN                      NaN
# 3           NaN                      NaN
# 4           NaN                      NaN
# 5           NaN                      NaN
#
#                                              org_url  \
# 0                                                NaN
# 2                           https://www.telekom.com/
# 3                                                NaN
# 4  https://www.enbw.com/company/investors/bonds/e...
# 5  https://www.eon.com/de/investoren/anleihen/e-d...
#
#                                 id
# 0  https://permid.org/1-5071549731
# 2  https://permid.org/1-4296543170
# 3  https://permid.org/1-4296653814
# 4  https://permid.org/1-4296930961
# 5  https://permid.org/1-4296072717

# %%
cols = list(final_df.columns)
reordered = ['organizationName',
             'org_perm_id',
             'id',
             'orgSubtype',
             'prefLabel',
             'rdfs:comment',
             'sector_perm_id',
             'trbc:BusinessClassificationCode',
             'hasPrimaryEconomicSector',
             'mdaas:HeadquartersAddress',
             'tr-org:hasHeadquartersPhoneNumber',
             'org_url',
             'primaryTicker',
             'hasHoldingClassification',
             'tr-org:hasLEI']

# %%
final_df = final_df[reordered]

# %%
final_df = final_df.rename(columns={'org_perm_id': 'orgID', 'id': 'orgID_URL','prefLabel': 'businessSector','rdfs:comment':'busSect_description', 'sector_perm_id':'busSectID', 'trbc:BusinessClassificationCode':'Business_ClassCode', 'hasPrimaryEconomicSector':'EconomicSectID_URL','mdaas:HeadquartersAddress':'HQ_Address', 'tr-org:hasHeadquartersPhoneNumber':'HQ_PhoneNumber','org_url':'orgURL','tr-org:hasLEI':'LEI'})

# %%
final_df
# Out:
#                               organizationName       orgID  \
# 0                 Elia Transmission Belgium NV  5071549731
# 2    Deutsche Telekom International Finance BV  4296543170
# 3                            innogy Finance BV  4296653814
# 4                EnBW International Finance BV  4296930961
# 5                E On International Finance BV  4296072717
# ..                                         ...         ...
# 448                   Reseaux Cables De France  4296680912
# 449                   Reseaux Cables De France  4296858525
# 450               Befimmo Property Services SA  5067178704
# 451         Brussels Airport Terminal Co SA NV  4296730050
# 452                           Solvay France SA  4296152148
#
#                            orgID_URL               orgSubtype  \
# 0    https://permid.org/1-5071549731                  Company
# 2    https://permid.org/1-4296543170  Special Purpose Vehicle
# 3    https://permid.org/1-4296653814  Special Purpose Vehicle
# 4    https://permid.org/1-4296930961  Special Purpose Vehicle
# 5    https://permid.org/1-4296072717  Special Purpose Vehicle
# ..                               ...                      ...
# 448  https://permid.org/1-4296680912                  Company
# 449  https://permid.org/1-4296858525                  Company
# 450  https://permid.org/1-5067178704                  Company
# 451  https://permid.org/1-4296730050                  Unknown
# 452  https://permid.org/1-4296152148                  Company
#
#                        businessSector  \
# 0                           Utilities
# 2         Telecommunications Services
# 3                           Utilities
# 4                           Utilities
# 5       Banking & Investment Services
# ..                                ...
# 448                 Mineral Resources
# 449  Industrial & Commercial Services
# 450                       Real Estate
# 451     Banking & Investment Services
# 452        Cyclical Consumer Products
#
#                                    busSect_description   busSectID  \
# 0    Producers and distributors of electricity, nat...  4294952820
# 2    Owners and operators of fixed line and wireles...  4294952825
# 3    Producers and distributors of electricity, nat...  4294952820
# 4    Producers and distributors of electricity, nat...  4294952820
# 5    Providers of retail, commercial and investment...  4294952739
# ..                                                 ...         ...
# 448  Miners and processors of steel, aluminum, prec...  4294952773
# 449  Providers of construction, engineering, commer...  4294952762
# 450  Developers and managers of real estate operati...  4294952860
# 451  Providers of retail, commercial and investment...  4294952739
# 452  Manufacturers and producers of durable goods s...  4294952745
#
#     Business_ClassCode               EconomicSectID_URL  \
# 0                 5910  https://permid.org/1-4294952821
# 2                 5740  https://permid.org/1-4294952723
# 3                 5910  https://permid.org/1-4294952821
# 4                 5910  https://permid.org/1-4294952821
# 5                 5510  https://permid.org/1-4294952740
# ..                 ...                              ...
# 448               5120  https://permid.org/1-4294952774
# 449               5220  https://permid.org/1-4294952767
# 450               6010  https://permid.org/1-1004365438
# 451               5510  https://permid.org/1-4294952740
# 452               5320  https://permid.org/1-4294952746
#
#                                             HQ_Address HQ_PhoneNumber  \
# 0    Boulevard De L'empereur 20\nBRUXELLES\nBRUXELL...            NaN
# 2    Stationsplein 8 K\nMAASTRICHT\nLIMBURG\n6221BT...            NaN
# 3    Willemsplein 4\nS-HERTOGENBOSCH\nNOORD-BRABANT...            NaN
# 4    Herikerbergweg 122\nAMSTERDAM\nNOORD-HOLLAND\n...            NaN
# 5    Kabelweg 37\nAMSTERDAM\nNOORD-HOLLAND\n1014 BA...            NaN
# ..                                                 ...            ...
# 448  Rua Lauro Mullerm, 116 Sala 3902 e 3903\nRio D...   552125080505
# 449  Challenger\n1, avenue Eugene Freyssinet\nSAINT...    33130603300
# 450                                          Hungary\n            NaN
# 451  25 Rue De Clichy\nPARIS\nILE-DE-FRANCE\n75009\...    33140758000
# 452                                      Ff\nGermany\n            NaN
#
#                                                 orgURL primaryTicker  \
# 0                                                  NaN           NaN
# 2                             https://www.telekom.com/           NaN
# 3                                                  NaN           NaN
# 4    https://www.enbw.com/company/investors/bonds/e...           NaN
# 5    https://www.eon.com/de/investoren/anleihen/e-d...           NaN
# ..                                                 ...           ...
# 448                        http://www.lorentzen.com.br           NaN
# 449               http://www.bouygues-construction.com           NaN
# 450                                                NaN           NaN
# 451                                                NaN           NaN
# 452                                                NaN           RHA
#
#     hasHoldingClassification                   LEI
# 0                        NaN  549300A3EZXECDLW2V25
# 2                        NaN  529900ERDFHS6C1M4U58
# 3                        NaN  5299005PIU82TA2PW123
# 4                        NaN  724500CNCIO1ZTJ0X675
# 5                        NaN  549300TG53AWJ719M814
# ..                       ...                   ...
# 448                      NaN                   NaN
# 449                      NaN  969500IL7U7UEI5ZYJ34
# 450                      NaN                   NaN
# 451                      NaN  549300850GMPCX5CK282
# 452                      NaN                   NaN
#
# [451 rows x 15 columns]

# %%
# save the df to csv file
# final_df.to_csv (r'/Users/gabbyvinco/Desktop/companies_final_451.csv', index = False, header=True)
